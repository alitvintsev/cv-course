# %% [markdown]
# Добрый день, уважаемый слушатель!
#
# В этом документе вы найдёте все необходимое для настройки всех систем, используемых для работы с уроками в GoogleColab.

# %% [markdown]
# #  Первые шаги
# Для начала, вам будут нужны будут аккаунты в следующих системах:

# %% [markdown]
# ## 1. [Google](https://www.google.com/)

# %% [markdown]
# **1.1 Вход в аккаунт**

# %% [markdown]
# Этот аккаунт будет использоваться для размещения необходимых для урока файлов, аренды виртуальной машины, также для упрощенной регистрации в остальных необходимых системах.

# %% [markdown]
# **1.2 Настройка диска**

# %% [markdown]
# На диске мы будем хранить следующие файлы, нужные для полноценной работы с Jupyer Notebook.
# Давайте создадим папки под них (делаем из-под google account):
# 1. Перейдем по ссылке: https://drive.google.com/drive/folders/1QB5qO0Zud-koiAHSSkMsSYIlDBjRFced?usp=share_link
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Добавить ярлык на свой google drive (Пункт: Add shortcut to drive):
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Делаем ярлык в MyDrive:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. [Blender](https://www.blender.org/)

# %% [markdown]
# Для работы с синтезом данных нам понадобиться приложение Blender. Устанавливается и работает Blender  на любое устройство c ОС: macOS, Linux, Windows
# Для скачивания воспользуемся видеоинструкцией по ссылке:
#
# https://drive.google.com/file/d/1OzBjWqCv1c92iqwNkvzm4lHyIodg0IG8/view?usp=sharing
#
# После скачивания установка запускается также как обычное приложение
